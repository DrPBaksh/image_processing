# %%
# !pip install bing_image_downloader

# %%
from bing_image_downloader import downloader
downloader.download('dogs', limit=100,  output_dir='dataset', force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to C:\Users\PeterBaksh\OneDrive - Corndel Ltd\Documents\public_git_repo\image_classifier\dataset\dogs
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 18 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://travelsandliving.com/wp-content/uploads/2016/01/adorable-smiling-dogs-24.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.cotf.edu/ete/images/modules/sevweath/dog.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://thegraphicsfairy.com/wp-content/uploads/2013/05/motherwithchildren.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.professionalsecurity.co.uk/wp-content/uploads/2013/02/dogd2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.oddee.com/wp-content/uploads/_media/imgs/articles2/a97115_g079_11-ALLIGATOR.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.luxurylifenews.com/wp-content/uploads/2017/05/dogs.jpg
# [%] File Downloaded !
#
# ...
